# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO(r"C:\my_files\cdsaml\yolov8n.pt")

# %%
image_path = r"C:\my_files\cdsaml\boy hammer[1].jpg"

# %%
image = cv2.imread(image_path)

# %%
results = model(image)
# Out:
# 0: 448x640 1 person, 1 tennis racket, 79.0ms
# Speed: 5.2ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
annotated_image = results[0].plot()

# %%
# Convert BGR to RGB for matplotlib display
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Optional: Hide axes
plt.show()
